# %% [markdown]
# <a href="https://colab.research.google.com/github/vcdemy/20230615-cht/blob/main/20230615_%E4%BA%BA%E8%87%89%E5%81%B5%E6%B8%AC(PIL).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 人臉偵測

# %% [markdown]
# ## 安裝套件

# %%
# !pip install face_recognition

# %%
# !pip install gradio

# %% [markdown]
# ## 載入套件

# %%
from PIL import Image, ImageDraw
import face_recognition

# %% [markdown]
# ## 讀取圖形

# %%
image = face_recognition.load_image_file("chou.jpg")

# %% [markdown]
# ## 人臉偵測

# %%
face_locations = face_recognition.face_locations(image)

# %% [markdown]
# ## 標出人臉位置

# %%
img = Image.fromarray(image)

# %%
draw = ImageDraw.Draw(img)

# %%
for face_location in face_locations:
  top, right, bottom, left = face_location
  draw.rectangle((left, top, right, bottom), outline="red", width=2)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=602x600 at 0x7F380889EDC0>

# %% [markdown]
# ## 建立使用者介面

# %%
import gradio as gr

# %%
def detect(image):
  face_locations = face_recognition.face_locations(image)
  img = Image.fromarray(image)
  draw = ImageDraw.Draw(img)
  for face_location in face_locations:
    top, right, bottom, left = face_location
    draw.rectangle((left, top, right, bottom), outline="red", width=2)
  return img

# %%
gr.Interface(detect, "image", "pil").launch(share=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/gradio/deprecation.py:43: UserWarning: You have unused kwarg parameters in Pil, please remove them: {'visibile': True}
#   warnings.warn(
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://ba23c154a29d80bb.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://ba23c154a29d80bb.gradio.app" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
